# %%
import pandas as pd

df = pd.read_csv("/opt/app/user/postdoc/Anaplasia_Classification/csvs/splits_selected_yes.csv")

df["mask_path"] = df["mask_path"].str.replace(
    "/data/temporary/",
    "/data/pathology/projects/",
    regex=False
)

df.to_csv("/opt/app/user/postdoc/Anaplasia_Classification/csvs/splits_selected_yes.csv", index=False)

# %%
import os

# %%
patches = [i for i in os.listdir('/opt/app/user/postdoc/Anaplasia_Classification/virchow2/2026-02-19_09_49/coordinates')]

# %%
len(patches)
# Out:
# 166
